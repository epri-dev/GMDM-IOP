# %%
# ! pip install cim-graph==0.4.1a0

# %%
import os
os.environ['CIMG_VALIDATION_LOG_LEVEL'] = 'DEBUG'
from cimgraph.databases import XMLFile
from cimgraph.models import FeederModel
from cimgraph import utils

namespaces={'cim': 'http://cim.ucaiug.io/CIM101#
            'gmdm': 'http://epri.com/gmdm/2025#',
            'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#'}

# %%
os.environ['CIMG_CIM_PROFILE'] = 'cimgraph.data_profile.cim18gmdm.connectivity'
file = XMLFile(filename='../ieee_9500_gmdm.xml', namespaces=namespaces)
network = FeederModel(container=None, connection=file)
utils.write_xml(network = network, filename='connectivity.xml', namespaces=namespaces)
utils.write_json_ld(network = network, filename='connectivity.jsonld', namespaces=namespaces)

# %%
os.environ['CIMG_CIM_PROFILE'] = 'cimgraph.data_profile.cim18gmdm.electrical'
file = XMLFile(filename='../ieee_9500_gmdm.xml', namespaces=namespaces)
network = FeederModel(container=None, connection=file)
utils.write_xml(network = network, filename='electrical.xml', namespaces=namespaces)
utils.write_json_ld(network = network, filename='electrical.jsonld', namespaces=namespaces)

# %%
os.environ['CIMG_CIM_PROFILE'] = 'cimgraph.data_profile.cim18gmdm.asset'
file = XMLFile(filename='../ieee_9500_gmdm.xml', namespaces=namespaces)
network = FeederModel(container=None, connection=file)
utils.write_xml(network = network, filename='asset.xml', namespaces=namespaces)
utils.write_json_ld(network = network, filename='asset.jsonld', namespaces=namespaces)

# %%
os.environ['CIMG_CIM_PROFILE'] = 'cimgraph.data_profile.cim18gmdm.location'
file = XMLFile(filename='../ieee_9500_gmdm.xml', namespaces=namespaces)
network = FeederModel(container=None, connection=file)
utils.write_xml(network = network, filename='location.xml', namespaces=namespaces)
utils.write_json_ld(network = network, filename='location.jsonld', namespaces=namespaces)

# %%
os.environ['CIMG_CIM_PROFILE'] = 'cimgraph.data_profile.cim18gmdm.marketnode'
file = XMLFile(filename='../ieee_9500_gmdm.xml', namespaces=namespaces)
network = FeederModel(container=None, connection=file)
utils.write_xml(network = network, filename='marketnode.xml', namespaces=namespaces)
utils.write_json_ld(network = network, filename='marketnode.jsonld', namespaces=namespaces)

# %%
os.environ['CIMG_VALIDATION_LOG_LEVEL'] = 'WARNING'
os.environ['CIMG_CIM_PROFILE'] = 'cimgraph.data_profile.cim18gmdm.canonical'
connectivity = XMLFile(filename='connectivity.xml', namespaces=namespaces)
electrical = XMLFile(filename='electrical.xml', namespaces=namespaces)
asset = XMLFile(filename='asset.xml', namespaces=namespaces)
location = XMLFile(filename='location.xml', namespaces=namespaces)
marketnode = XMLFile(filename='marketnode.xml', namespaces=namespaces)
# usagepoint = XMLFile(filename='usagepoint.xml', namespaces=namespaces)

conn_network = FeederModel(container=None, connection=connectivity)
conn_elec = FeederModel(container=None, connection=electrical, graph=conn_network.graph)
conn_elec_asset = FeederModel(container=None, connection=asset, graph=conn_elec.graph)
conn_elec_asset_location = FeederModel(container=None, connection=location, graph=conn_elec_asset.graph)
complete_network = FeederModel(container=None, connection=marketnode, graph=conn_elec_asset_location.graph)
# complete_network = FeederModel(container=None, connection=usagepoint, graph=conn_elec_asset_location_pnode.graph)
utils.write_xml(network=complete_network, filename='../merge.xml', namespaces=namespaces)
utils.write_json_ld(network=complete_network, filename='../merge.jsonld', namespaces=namespaces)

# %%
import os
os.environ['CIMG_VALIDATION_LOG_LEVEL'] = 'WARNING'

os.environ['CIMG_CIM_PROFILE'] = 'cimgraph.data_profile.cim18gmdm.canonical'
import cimgraph.data_profile.cim18gmdm.canonical as cim # must match env var

from cimgraph.databases import XMLFile
from cimgraph.models import FeederModel
from cimgraph import utils

namespaces={'cim': 'http://cim.ucaiug.io/CIM101#
            'gmdm': 'http://epri.com/gmdm/2025#',
            'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#'}

file = XMLFile(filename='../merge.xml', namespaces=namespaces)
network = FeederModel(container=None, connection=file)
# Out:
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01dd7e45e0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01da7b1cb0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01e5d46fc0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01e5d46cf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01e5d46a70>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01e5d467f0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01e5d46610>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01e5d461b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01e5d45ee0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01e5d45c60>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01e5d45800>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01cc266160>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01cc267bf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01ccc99a30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968a340>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968a570>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968a840>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968ab10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968ade0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968b0b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968b380>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968b650>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968b920>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968bbf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c968bec0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95001d0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95004a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9500770>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9500a40>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9500d10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9500fe0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95012b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9501580>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9501850>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9501b20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9501df0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95020c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9502390>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9502660>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9502930>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9502c00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9502ed0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95031a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9503470>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9503740>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9503a10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9503ce0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9503fb0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95142c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9514590>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9514860>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9514b30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9514e00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95150d0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95153a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9515670>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9515940>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9515c10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9515ee0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95161b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9516480>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9516750>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9516a20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9516cf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9516fc0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9517290>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9517560>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9517830>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9517b00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9517dd0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95280e0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95283b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9528680>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9528950>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9528c20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9528ef0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95291c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9529490>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9529760>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9529a30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9529d00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9529fd0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952a2a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952a570>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952a840>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952ab10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952ade0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952b0b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952b380>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952b650>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952b920>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952bbf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c952bec0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95401d0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95404a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9540770>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9540a40>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9540d10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9540fe0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95412b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9541580>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9541850>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9541b20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9541df0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95420c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9542390>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9542660>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9542930>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9542c00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9542ed0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95431a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9543470>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9543740>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9543a10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9543ce0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9543fb0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95542c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9554590>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9554860>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9554b30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9554e00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95550d0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95553a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9555670>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9555940>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9555c10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9555ee0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95561b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9556480>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9556750>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9556a20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9556cf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9556fc0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9557290>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9557560>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9557830>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9557b00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9557dd0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95600e0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95603b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9560680>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9560950>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9560c20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9560ef0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95611c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9561490>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9561760>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9561a30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9561d00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9561fd0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95622a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9562570>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9562840>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9562b10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9562de0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95630b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9563380>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9563650>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9563920>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9563bf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9563ec0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95741d0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95744a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9574770>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9574a40>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9574d10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9574fe0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95752b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9575580>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9575850>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9575b20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9575df0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95760c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9576390>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9576660>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9576930>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9576c00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9576ed0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95771a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9577470>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9577740>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9577a10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9577ce0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9577fb0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95882c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9588590>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9588860>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9588b30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9588e00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95890d0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95893a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9589670>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9589940>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9589c10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c9589ee0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958a1b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958a480>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958a750>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958aa20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958acf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958afc0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958b290>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958b560>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958b830>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958bb00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c958bdd0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a00e0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a03b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a0680>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a0950>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a0c20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a0ef0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a11c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a1490>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a1760>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a1a30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a1d00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a1fd0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a22a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a2570>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a2840>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a2b10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a2de0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a30b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a3380>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a3650>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a3920>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a3bf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c95a3ec0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b81d0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b84a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b8770>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b8a40>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b8d10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b8fe0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b92b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b9580>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b9850>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b9b20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93b9df0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93ba0c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93ba390>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93ba660>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93ba930>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93bac00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93baed0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93bb1a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93bb470>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93bb740>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93bba10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93bbce0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93bbfb0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cc2c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cc590>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cc860>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93ccb30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cce00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cd0d0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cd3a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cd670>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cd940>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cdc10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cdee0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93ce1b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93ce480>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93ce750>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cea20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cecf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cefc0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cf290>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cf560>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cf830>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cfb00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93cfdd0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93dc0e0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93dc3b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93dc680>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93dc950>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93dcc20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93dcef0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93dd1c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93dd490>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93dd760>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93dda30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93ddd00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93ddfd0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93de2a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93de570>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93de840>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegment' at 0x7b01c93deb10>. This may be caused by an invalid namespace
# ...
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7eaffb0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec0220>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec0450>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec0680>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec08b0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec0ae0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec0d10>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec0f40>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec1170>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec13f0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec1620>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec1850>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec1a80>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec1cb0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec1ee0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec2110>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec2340>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec2570>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec27a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec29d0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec2c00>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec2e30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec3060>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec3290>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec34c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec36f0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec3920>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec3b50>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec3d80>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ec3fb0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed0220>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed04a0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed06d0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed0900>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed0b30>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed0d60>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed0f90>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed11c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed13f0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed1620>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed1850>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed1a80>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed1cb0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed1ee0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed2160>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed2390>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed25c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed27f0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed2a20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed2ca0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed2ed0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed3100>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed3330>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed3560>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed3790>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed39c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed3bf0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ed3e20>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ee0090>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ee02c0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ee04f0>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ee0720>. This may be caused by an invalid namespace
# Unable to parse <Element '{http://cim.ucaiug.io/Grid18v15_Enterprise14v04_Market04v18#}ACLineSegmentPhase' at 0x7b01c7ee0950>. This may be caused by an invalid namespace
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 16
#      11 namespaces={'cim': 'http://cim.ucaiug.io/CIM101#',
#      12             'gmdm': 'http://epri.com/gmdm/2025#',
#      13             'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#'}
#      15 file = XMLFile(filename='../merge.xml', namespaces=namespaces)
# ---> 16 network = FeederModel(container=None, connection=file)
#
# File <string>:11, in __init__(self, container, connection, distributed, graph, incrementals, __class_iter__, topology_message, distributed_areas)
#
# File ~/CIM-Graph/cimgraph/models/feeder_model.py:54, in FeederModel.__post_init__(self)
#      51         self.__initialize_distributed_model()
#      52     else:
#      53         # Otherwise build centralized network model
# ---> 54         self.__initialize_centralized_model()
#      55 else:    # Log error thant no connection was specified
#      56     _log.error('A ConnectionInterface must be specified')
#
# File ~/CIM-Graph/cimgraph/models/feeder_model.py:62, in FeederModel.__initialize_centralized_model(self)
#      60 def __initialize_centralized_model(self) -> None:
#      61     # Build graph model using database-specific routine
# ---> 62     self.graph = self.connection.create_new_graph(self.container, self.graph)
#
# File ~/CIM-Graph/cimgraph/databases/fileparsers/xml_parser.py:112, in XMLFile.create_new_graph(self, container, graph)
#     110 if self.root is not None:
#     111     for element in self.root:
# --> 112         self.parse_nodes(element)
#     114     for element in self.root:
#     115         self.parse_edges(element)
#
# File ~/CIM-Graph/cimgraph/databases/fileparsers/xml_parser.py:139, in XMLFile.parse_nodes(self, element)
#     137             pass
#     138 if class_name is None:
# --> 139     _log.error(f'Unable to parse {element}. This may be caused by an invalid namespace')
#     140     return None
#     142 if class_name in self.cim.__all__:
#     143     # print(class_name)
#
# File /usr/lib/python3.10/logging/__init__.py:1506, in Logger.error(self, msg, *args, **kwargs)
#    1497 """
#    1498 Log 'msg % args' with severity 'ERROR'.
#    1499
#    (...)
#    1503 logger.error("Houston, we have a %s", "major problem", exc_info=1)
#    1504 """
#    1505 if self.isEnabledFor(ERROR):
# -> 1506     self._log(ERROR, msg, args, **kwargs)
#
# File /usr/lib/python3.10/logging/__init__.py:1624, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1621         exc_info = sys.exc_info()
#    1622 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1623                          exc_info, func, extra, sinfo)
# -> 1624 self.handle(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1634, in Logger.handle(self, record)
#    1627 """
#    1628 Call the handlers for the specified record.
#    1629
#    1630 This method is used for unpickled records received from a socket, as
#    1631 well as those created locally. Logger-level filtering is applied.
#    1632 """
#    1633 if (not self.disabled) and self.filter(record):
# -> 1634     self.callHandlers(record)
#
# File /usr/lib/python3.10/logging/__init__.py:1704, in Logger.callHandlers(self, record)
#    1702 if lastResort:
#    1703     if record.levelno >= lastResort.level:
# -> 1704         lastResort.handle(record)
#    1705 elif raiseExceptions and not self.manager.emittedNoHandlerWarning:
#    1706     sys.stderr.write("No handlers could be found for logger"
#    1707                      " \"%s\"\n" % self.name)
#
# File /usr/lib/python3.10/logging/__init__.py:968, in Handler.handle(self, record)
#     966 self.acquire()
#     967 try:
# --> 968     self.emit(record)
#     969 finally:
#     970     self.release()
#
# File /usr/lib/python3.10/logging/__init__.py:1104, in StreamHandler.emit(self, record)
#    1102     # issue 35046: merged two stream.writes into one.
#    1103     stream.write(msg + self.terminator)
# -> 1104     self.flush()
#    1105 except RecursionError:  # See issue 36272
#    1106     raise
#
# File /usr/lib/python3.10/logging/__init__.py:1084, in StreamHandler.flush(self)
#    1082 try:
#    1083     if self.stream and hasattr(self.stream, "flush"):
# -> 1084         self.stream.flush()
#    1085 finally:
#    1086     self.release()
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/iostream.py:564, in OutStream.flush(self)
#     562     self.pub_thread.schedule(evt.set)
#     563     # and give a timeout to avoid
# --> 564     if not evt.wait(self.flush_timeout):
#     565         # write directly to __stderr__ instead of warning because
#     566         # if this is happening sys.stderr may be the problem.
#     567         print("IOStream.flush timed out", file=sys.__stderr__)
#     568 else:
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
